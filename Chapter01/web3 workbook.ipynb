# %%
# !pip install web3
# Out:
# Collecting web3
#   Downloading web3-7.6.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting eth-abi>=5.0.1 (from web3)
#   Downloading eth_abi-5.1.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting eth-account>=0.13.1 (from web3)
#   Downloading eth_account-0.13.4-py3-none-any.whl.metadata (5.3 kB)
# Collecting eth-hash>=0.5.1 (from eth-hash[pycryptodome]>=0.5.1->web3)
#   Downloading eth_hash-0.7.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting eth-typing>=5.0.0 (from web3)
#   Downloading eth_typing-5.1.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting eth-utils>=5.0.0 (from web3)
#   Downloading eth_utils-5.1.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting hexbytes>=1.2.0 (from web3)
#   Downloading hexbytes-1.3.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: aiohttp>=3.7.4.post0 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from web3) (3.9.5)
# Requirement already satisfied: pydantic>=2.4.0 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from web3) (2.5.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from web3) (2.32.2)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from web3) (4.11.0)
# Collecting types-requests>=2.0.0 (from web3)
#   Downloading types_requests-2.32.0.20241016-py3-none-any.whl.metadata (1.9 kB)
# Collecting websockets<14.0.0,>=10.0.0 (from web3)
#   Downloading websockets-13.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Collecting pyunormalize>=15.0.0 (from web3)
#   Downloading pyunormalize-16.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: pywin32>=223 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from web3) (305.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (1.9.3)
# Collecting parsimonious<0.11.0,>=0.10.0 (from eth-abi>=5.0.1->web3)
#   Downloading parsimonious-0.10.0-py3-none-any.whl.metadata (25 kB)
# Collecting bitarray>=2.4.0 (from eth-account>=0.13.1->web3)
#   Downloading bitarray-3.0.0-cp312-cp312-win_amd64.whl.metadata (33 kB)
# Collecting eth-keyfile<0.9.0,>=0.7.0 (from eth-account>=0.13.1->web3)
#   Downloading eth_keyfile-0.8.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting eth-keys>=0.4.0 (from eth-account>=0.13.1->web3)
#   Downloading eth_keys-0.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting eth-rlp>=2.1.0 (from eth-account>=0.13.1->web3)
#   Downloading eth_rlp-2.1.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting rlp>=1.0.0 (from eth-account>=0.13.1->web3)
#   Downloading rlp-4.0.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting ckzg>=2.0.0 (from eth-account>=0.13.1->web3)
#   Downloading ckzg-2.0.1-cp312-cp312-win_amd64.whl.metadata (718 bytes)
# Collecting pycryptodome<4,>=3.6.6 (from eth-hash[pycryptodome]>=0.5.1->web3)
#   Downloading pycryptodome-3.21.0-cp36-abi3-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: cytoolz>=0.10.1 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from eth-utils>=5.0.0->web3) (0.12.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from pydantic>=2.4.0->web3) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from pydantic>=2.4.0->web3) (2.14.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from requests>=2.23.0->web3) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from requests>=2.23.0->web3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from requests>=2.23.0->web3) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from requests>=2.23.0->web3) (2024.7.4)
# Requirement already satisfied: toolz>=0.8.0 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from cytoolz>=0.10.1->eth-utils>=5.0.0->web3) (0.12.0)
# Requirement already satisfied: regex>=2022.3.15 in c:\users\user\appdata\local\anaconda3\lib\site-packages (from parsimonious<0.11.0,>=0.10.0->eth-abi>=5.0.1->web3) (2023.10.3)
# Downloading web3-7.6.1-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    - -------------------------------------- 0.1/1.4 MB 3.4 MB/s eta 0:00:01
#    --- ------------------------------------ 0.1/1.4 MB 1.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.4 MB 1.5 MB/s eta 0:00:01
#    ------- -------------------------------- 0.3/1.4 MB 1.2 MB/s eta 0:00:01
#    ------------- -------------------------- 0.5/1.4 MB 1.8 MB/s eta 0:00:01
#    ------------- -------------------------- 0.5/1.4 MB 1.6 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.6/1.4 MB 1.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.0/1.4 MB 2.5 MB/s eta 0:00:01
#    -------------------------------- ------- 1.1/1.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 2.7 MB/s eta 0:00:00
# Downloading eth_abi-5.1.0-py3-none-any.whl (29 kB)
# Downloading eth_account-0.13.4-py3-none-any.whl (581 kB)
#    ---------------------------------------- 0.0/581.4 kB ? eta -:--:--
#    --------------------------------------- 581.4/581.4 kB 12.2 MB/s eta 0:00:00
# Downloading eth_hash-0.7.1-py3-none-any.whl (8.0 kB)
# Downloading eth_typing-5.1.0-py3-none-any.whl (19 kB)
# Downloading eth_utils-5.1.0-py3-none-any.whl (100 kB)
#    ---------------------------------------- 0.0/100.5 kB ? eta -:--:--
#    ---------------------------------------- 100.5/100.5 kB 5.6 MB/s eta 0:00:00
# Downloading hexbytes-1.3.0-py3-none-any.whl (4.9 kB)
# Downloading pyunormalize-16.0.0-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.2 kB ? eta -:--:--
#    ---------------------------------------- 49.2/49.2 kB 2.4 MB/s eta 0:00:00
# Downloading types_requests-2.32.0.20241016-py3-none-any.whl (15 kB)
# Downloading websockets-13.1-cp312-cp312-win_amd64.whl (159 kB)
#    ---------------------------------------- 0.0/159.1 kB ? eta -:--:--
#    ---------------------------------------- 159.1/159.1 kB 4.8 MB/s eta 0:00:00
# Downloading bitarray-3.0.0-cp312-cp312-win_amd64.whl (121 kB)
#    ---------------------------------------- 0.0/121.7 kB ? eta -:--:--
#    ---------------------------------------- 121.7/121.7 kB 7.0 MB/s eta 0:00:00
# Downloading ckzg-2.0.1-cp312-cp312-win_amd64.whl (98 kB)
#    ---------------------------------------- 0.0/98.3 kB ? eta -:--:--
#    ---------------------------------------- 98.3/98.3 kB 5.5 MB/s eta 0:00:00
# Downloading eth_keyfile-0.8.1-py3-none-any.whl (7.5 kB)
# Downloading eth_keys-0.6.0-py3-none-any.whl (21 kB)
# Downloading eth_rlp-2.1.0-py3-none-any.whl (5.1 kB)
# Downloading parsimonious-0.10.0-py3-none-any.whl (48 kB)
#    ---------------------------------------- 0.0/48.4 kB ? eta -:--:--
#    ---------------------------------------- 48.4/48.4 kB 2.4 MB/s eta 0:00:00
# Downloading pycryptodome-3.21.0-cp36-abi3-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.8 MB 6.8 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.8 MB 10.1 MB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 7.2 MB/s eta 0:00:00
# Downloading rlp-4.0.1-py3-none-any.whl (20 kB)
# Installing collected packages: ckzg, bitarray, websockets, types-requests, pyunormalize, pycryptodome, parsimonious, hexbytes, eth-typing, eth-hash, eth-utils, rlp, eth-keys, eth-abi, eth-rlp, eth-keyfile, eth-account, web3
# Successfully installed bitarray-3.0.0 ckzg-2.0.1 eth-abi-5.1.0 eth-account-0.13.4 eth-hash-0.7.1 eth-keyfile-0.8.1 eth-keys-0.6.0 eth-rlp-2.1.0 eth-typing-5.1.0 eth-utils-5.1.0 hexbytes-1.3.0 parsimonious-0.10.0 pycryptodome-3.21.0 pyunormalize-16.0.0 rlp-4.0.1 types-requests-2.32.0.20241016 web3-7.6.1 websockets-13.1

# %%
from web3 import Web3
print(Web3)
# Out:
# <class 'web3.main.Web3'>

# %%
ganache_url = "http://127.0.0.1:8545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

print("Are we connected to the blockchain?:", web3.is_connected())
# Out:
# Are we connected to the blockchain?: False

# %%
import socket

# Get the local machine's IP address
hostname = socket.gethostname()
ip_address = socket.gethostbyname(hostname)

print("Your local machine's IP address:", ip_address)
# Out:
# Your local machine's IP address: 172.25.112.1

# %%
ganache_url = "http://172.25.112.1:8545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

# Check connection
print("Are we connected to the blockchain?:", web3.is_connected())
# Out:
# Are we connected to the blockchain?: False

# %%
npm install -g ganache
# Out:
#   Cell In[19], line 1
#     npm install -g ganache
#         ^
# SyntaxError: invalid syntax
